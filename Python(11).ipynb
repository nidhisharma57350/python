# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhisharma57350-ops/python/blob/main/Python(11).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number=int(input("enter number"))
a=[]
while number>0:
  remender=number%2
  number=number//2
  a.append(remender)
print(a)
print(a[::-1])
# Out:
# enter number25
# [1, 0, 0, 1, 1]
# [1, 1, 0, 0, 1]

# %%
number = int(input("enter number:"))
a = []
while number>0:
  remender = number%2
  number = number //2
  a.append(remender)
a.reverse()
print(a)
# Out:
# enter number:5
# [1, 0, 1]

# %%
number=int(input("enter number"))
a=""
while number>0:
  remender=number%2
  number=number//2
  a=str(remender)+a
  print(a)
# Out:
# enter number25
# 1
# 01
# 001
# 1001
# 11001

# %%
number=int(input("enter number"))
a=""
while number>0:
  remender=number%2
  number=number//2
  a = str(remender) + a
  print(a)
# Out:
# enter number25
# 1
# 01
# 001
# 1001
# 11001

# %%
number=25  # doubt.
rev=0
while number>0:
  digit=number%2
  number=number//2
  rev=rev*10+digit
  print(rev)
# Out:
# 1
# 10
# 100
# 1001
# 10011

# %%
number = 101
a = []
dec = 0
while number>0:
    digit  = number%10
    number = number//10
    a.append(digit)
a.reverse()
print(a)
for i in range(len(a)):
    dec = dec + a[i] * 2**i
print(dec)
# Out:
# [1, 0, 1]
# 5

# %%
a="11001"
dec=0
for i in range(len(str(a))): # it can be happened by using while loop.
  digit=int(a)%10
  a=int(a)//10
  dec=dec+2**i*digit
print(dec)
# Out:
# 25

# %%
n=int(input("enter number"))
a=[]
while n>0:
   remender=n%8
   n=n//8
   a.append(remender)
   b=a[::-1]
   print(b)
# Out:
# enter number56
# [0]
# [7, 0]

# %%
n="70"
dec=0
for i in range(len(str(n))):
   digit=int(n)%10
   n=int(n)//10
   dec=dec+8**i*digit
   print(dec)
# Out:
# 0
# 56

# %%
n=int(input("enter number"))
a=[]
while n>0:
   remender=n%16
   n=n//16
   a.append(remender)
   b=a[::-1]
   print(b)
# Out:
# enter number50
# [2]
# [3, 2]

# %%
n="32"
dec=0
for i in range(len(str(n))):
   digit=int(n)%10
   n=int(n)//10
   dec=dec+16**i*digit
   print(dec)
# Out:
# 2
# 50

# %%
# a="sppsqallq"
a=["s","p","p","s","q","a","l","l","q"]
b=[]
c=[]
count=0
for i in a:
  if i not in b:
    b.append(i)
    c.append(0)
for i in range(len(a)):
  index=b.index(a[i])
  c[index]=c[index]+1
print(b)
print(c)
# Out:
# ['s', 'p', 'q', 'a', 'l']
# [2, 2, 2, 1, 2]

# %%
n=int(input("enter the value of n"))
r=int(input("enter the value of r"))
a=n-r
print(a)

fact=1
for i in range(1,n+1):
  fact=fact*i
print(fact)
fact1=1
for i in range(1,a+1):
  fact1=fact1*i
  print(fact1)
permutation=fact/fact1
print(permutation)
# Out:
# enter the value of n5
# enter the value of r2
# 3
# 120
# 1
# 2
# 6
# 20.0

# %%
n=int(input("enter the value of n"))
r=int(input("enter the value of r"))
a=int(n-r)
print(a)
fact=1
for i in range(1,n+1):
   fact=fact*i
print(fact)
fact1=1
for j in range(1,a+1):
   fact1=fact1*j
print(fact1)
fact2=1
for k in range(1,r+1):
   fact2=fact2*k
print(fact2)
fact3=fact1*fact2
combination=fact/fact3
print(combination)
# Out:
# enter the value of n5
# enter the value of r2
# 3
# 120
# 6
# 2
# 10.0

# %%
n=int(input("enter the value of n"))
r=int(input("enter the value of r"))
a=int(n-r)
print(a)
fact=1
for i in range(1,n+1):
   fact=fact*i
print(fact)
fact1=1
for j in range(1,a+1):
   fact1=fact1*j
print(fact1)
fact2=1
for k in range(1,r+1):
   fact2=fact2*k
print(fact2)
fact3=fact1*fact2
combination=fact/(fact1*fact2)
print(combination)
# Out:
# enter the value of n5
# enter the value of r2
# 3
# 120
# 6
# 2
# 10.0

# %%
word="banana"
n=6
fact=1
for i in range(1,n+1):
  fact=fact*i
print(fact)
a=3
fact1=1
for i in range(1,a+1):
  fact1=fact1*i
print(fact1)
b=2
fact2=1
for i in range(1,b+1):
  fact2=fact2*i
print(fact2)
result=fact/(fact1*fact2)
print(result)
# Out:
# 720
# 6
# 2
# 60.0

# %%
a="maverick"
vowel="aeiou"
vowel_count=0
consonent_count=0
for i in range(len(str(a))):
   if a[i] in vowel:
     vowel_count=vowel_count+1
     print("vowel counts are",vowel_count)
   else:
     consonent_count=consonent_count+1
     print("consonent counts are",consonent_count)
# Out:
# consonent counts are 1
# vowel counts are 1
# consonent counts are 2
# vowel counts are 2
# consonent counts are 3
# vowel counts are 3
# consonent counts are 4
# consonent counts are 5

# %%
a=input("enter your word")
vowel="aeiouAEIOU"
consonents="bcdfghjklmnpqrstvwxyzBCDFGHJKLMNPQRSTVWXYZ"
vowel_count=0
consonent_count=0
another_count=0
for i in range(len(str(a))):
   if a[i] in vowel:
     vowel_count=vowel_count+1
     print("vowel counts are",vowel_count)
   elif a[i] in consonents:
     consonent_count=consonent_count+1
     print("consonent counts are",consonent_count)
   else:
     pass
# Out:
# enter your wordhjhbj
# consonent counts are 1
# consonent counts are 2
# consonent counts are 3
# consonent counts are 4
# consonent counts are 5

# %%
a=[2,4,2,5,3,4,5,6,7,2]
unique_a=[]
frequency_a=[]
for i in a:
    if i not in unique_a:
        unique_a.append(i)
        frequency_a.append(0)
for i in range(len(a)):
    index=unique_a.index(a[i])
    frequency_a[index]=frequency_a[index]+1
print(unique_a)
print(frequency_a)
# Out:
# [2, 4, 5, 3, 6, 7]
# [3, 2, 2, 1, 1, 1]
